# %%
#   A
for i in range(11):
  for j in range(11):
    if i==0 or j==0  or j==10 or i==5:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# ***********
# *         *
# *         *
# *         *
# *         *
# *         *

# %%
#   B
for i in range(11):
  for j in range(11):
    if i==0 or j==0  or j==10 or i==10 or i==5:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# ***********
# *         *
# *         *
# *         *
# *         *
# ***********

# %%
#   C
for i in range(11):
  for j in range(11):
    if i==0 or j==0  or i==10:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ***********

# %%
#  D
for i in range(11):
  for j in range(11):
    if i==0 or j==0  or j==10 or i==10:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# ***********

# %%
#   E
for i in range(11):
  for j in range(11):
    if i==0 or j==0  or i==5 or i==10:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *
# *
# *
# *
# ***********
# *
# *
# *
# *
# ***********

# %%
#   F
for i in range(11):
  for j in range(11):
    if i==0 or j==0  or i==5:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *
# *
# *
# *
# ***********
# *
# *
# *
# *
# *

# %%
#  G
for i in range(11):
  for j in range(11):
    if i==0 or j==0 or i==10 or (i>=5 and j==10) or (i>=5 and j>=6) and (i==5) :
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *
# *
# *
# *
# *     *****
# *         *
# *         *
# *         *
# *         *
# ***********

# %%
#  H
for i in range(11):
  for j in range(11):
    if  j==0 or  i==5 or j==10  :
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
# *         *
# *         *
# *         *
# *         *
# ***********
# *         *
# *         *
# *         *
# *         *
# *         *

# %%
#  I
for i in range(11):
  for j in range(11):
    if  i==0 or j==5 or i==10:
     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
#      *
#      *
#      *
#      *
#      *
#      *
#      *
#      *
#      *
# ***********

# %%
#   J
for i in range(11):
  for j in range(11):
    if  i==0 or j==5 or (i==10 and j<=5)or (i>=7 and j==0):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
#      *
#      *
#      *
#      *
#      *
#      *
# *    *
# *    *
# *    *
# ******

# %%
#  K
for i in range(11):
  for j in range(11):
    if  j==5 or (i==j and j>=5 )or (j==10-i and j>=5 ) :

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
#      *    *
#      *   *
#      *  *
#      * *
#      **
#      *
#      **
#      * *
#      *  *
#      *   *
#      *    *

# %%
#   L
for i in range(11):
  for j in range(11):
    if j==0 or i==10:

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ***********

# %%
#  M
for i in range(11):
  for j in range(11):
    if j==0  or j==10 or (i==j and j<=5) or (j==10-i and j>=5 ):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
# **       **
# * *     * *
# *  *   *  *
# *   * *   *
# *    *    *
# *         *
# *         *
# *         *
# *         *
# *         *

# %%
#   N
for i in range(11):
  for j in range(11):
    if j==0  or j==10 or (i==j):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
# **        *
# * *       *
# *  *      *
# *   *     *
# *    *    *
# *     *   *
# *      *  *
# *       * *
# *        **
# *         *

# %%
#   O
for i in range(11):
  for j in range(11):
    if j==0  or j==10 or i==0 or i==10:

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# ***********

# %%
#   P
for i in range(11):
  for j in range(11):
    if j==0  or (j==10 and i<=5) or i==0 or i==5 :

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# ***********
# *
# *
# *
# *
# *

# %%
#   Q
for i in range(11):
  for j in range(11):
    if j==0  or j==10 or i==10 or i==0  or (i==j and j>=5  ):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# *    *    *
# *     *   *
# *      *  *
# *       * *
# *        **
# ***********

# %%
#   R
for i in range(11):
  for j in range(11):
    if j==0  or (j==10 and i<=5 )  or i==0  or i==5 or (i==j and j>=5  ):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *         *
# *         *
# *         *
# *         *
# ***********
# *     *
# *      *
# *       *
# *        *
# *         *

# %%
#    S
for i in range(11):
  for j in range(11):
    if (j==0 and i<=5 )  or (j==10 and i>=5 )  or i==0  or i==5 or  i==10:

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
# *
# *
# *
# *
# ***********
#           *
#           *
#           *
#           *
# ***********

# %%
#   T
for i in range(11):
  for j in range(11):
    if     i==0 or j==5:

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
#      *
#      *
#      *
#      *
#      *
#      *
#      *
#      *
#      *
#      *

# %%
#   U
for i in range(11):
  for j in range(11):
    if i==10  or j==10 or j==0 or  i==10 :

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
# ***********

# %%
for i in range(11):
  for j in range(11):
    if  (j==0 and i<=5) or (j==10 and i<=5 ) or (i==j+5)or (j==10-i+5)  :

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
# *         *
# *         *
# *         *
# *         *
# *         *
#  *       *
#   *     *
#    *   *
#     * *
#      *

# %%
#   W
for i in range(11):
  for j in range(11):
    if  j==10 or j==0 or (i==j and j>=5) or (j==10-i and j<=5 ):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
# *         *
# *         *
# *         *
# *         *
# *    *    *
# *   * *   *
# *  *   *  *
# * *     * *
# **       **
# *         *

# %%
#   X
for i in range(11):
  for j in range(11):
    if  (i==j) or (j==10-i):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
#  *       *
#   *     *
#    *   *
#     * *
#      *
#     * *
#    *   *
#   *     *
#  *       *
# *         *

# %%
#   Y
for i in range(11):
  for j in range(11):
    if  (i==j) or (j==10-i):

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# *         *
#  *       *
#   *     *
#    *   *
#     * *
#      *
#     *
#    *
#   *
#  *
# *

# %%
#   Z
for i in range(11):
  for j in range(11):
    if  i==0 or (j==10-i) or i==10:

     print("*",end="")
    else:
      print(" ",end="")

  print()
# Out:
# ***********
#          *
#         *
#        *
#       *
#      *
#     *
#    *
#   *
#  *
# ***********
